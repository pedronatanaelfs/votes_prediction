# %%
import pandas as pd

# %%
# Load the required files
vote_sessions = pd.read_csv("../data/vote_sessions_full.csv", usecols=["id", "data", "aprovacao", "propositionID", "siglaOrgao", "year", "author_type", "num_authors", "theme", "legislatura", "Governo", "Oposição", "GOV."])
content_cluster = pd.read_csv("../Content/prop_content.csv", usecols=["id", "content"])
authors_pop = pd.read_csv("../Author's Popularity/author_popularity.csv", usecols=["idVotacao", "popularity"])
authors_comm = pd.read_csv("../Author's Group/authors_community_dataset_one_year_window.csv", usecols=["id", "author_prev_community", "prev_community_0_size", "prev_community_1_size", "prev_community_2_size"])

# Merge vote_sessions with content_cluster
merged_df = vote_sessions.merge(
    content_cluster, left_on="id", right_on="id", how="left"
)

# Merge with authors_pop (id in vote_sessions matches idVotacao in authors_pop)
merged_df = merged_df.merge(
    authors_pop, left_on="id", right_on="idVotacao", how="left"
)

# Merge with authors_comm (id in vote_sessions matches id in authors_comm)
merged_df = merged_df.merge(
    authors_comm, left_on="id", right_on="id", how="left"
)

# Remove duplicated columns: "propositionID", "idVotacao"
merged_df = merged_df.drop(columns=["propositionID", "idVotacao"])

# Keep only unique values of the 'id' column
merged_df = merged_df.drop_duplicates(subset=["id"], keep="first")

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9260 entries, 0 to 2099179
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     9260 non-null   object
#  1   data                   9260 non-null   object
#  2   siglaOrgao             9260 non-null   object
#  3   aprovacao              8914 non-null   float64
#  4   year                   9260 non-null   int64
#  5   GOV.                   9260 non-null   int64
#  6   Governo                9260 non-null   int64
#  7   Oposição               9260 non-null   int64
#  8   author_type            9260 non-null   object
#  9   num_authors            9260 non-null   int64
#  10  theme                  9252 non-null   object
#  11  legislatura            9260 non-null   int64
#  12  content                9260 non-null   object
#  13  popularity             1990 non-null   float64
#  14  author_prev_community  4130 non-null   float64
#  15  prev_community_0_size  8973 non-null   float64
#  16  prev_community_1_size  8973 non-null   float64
#  17  prev_community_2_size  9260 non-null   int64
# dtypes: float64(5), int64(7), object(6)
# memory usage: 1.3+ MB

# %%
print("Valores únicos da coluna 'GOV.':", merged_df['GOV.'].unique())
print("Valores únicos da coluna 'Governo':", merged_df['Governo'].unique())
# Out:
# Valores únicos da coluna 'GOV.': [ 0  1 -1]
# Valores únicos da coluna 'Governo': [ 0  1 -1]

# %%
# Calcula a porcentagem de linhas em que 'GOV.' diverge de 'Governo'
total_linhas = len(merged_df)
divergentes_mask = merged_df['GOV.'] != merged_df['Governo']
divergentes = divergentes_mask.sum()
percentual_divergentes = (divergentes / total_linhas) * 100
print(f"Percentual de linhas em que 'GOV.' diverge de 'Governo': {percentual_divergentes:.2f}%")

# Mostra alguns exemplos dessas linhas que divergem
exemplos_divergentes = merged_df.loc[divergentes_mask, ['id', 'GOV.', 'Governo']].head(10)
print("Exemplos de linhas divergentes entre 'GOV.' e 'Governo':")
print(exemplos_divergentes)
# Out:
# Percentual de linhas em que 'GOV.' diverge de 'Governo': 16.59%
# Exemplos de linhas divergentes entre 'GOV.' e 'Governo':
#              id  GOV.  Governo
# 101   115155-58     1        0
# 368  125572-116     1        0
# 492   145211-10     1        0
# 535    32147-56     1        0
# 557    150930-5     1        0
# 558    151030-5     1        0
# 796    252929-5     1        0
# 828   126541-68     1        0
# 837   140174-83    -1        0
# 938   109175-70     1        0

# %%
def resolve_gov_orientation(row):
    if row['GOV.'] == row['Governo']:
        return row['GOV.']
    else:
        # Se discordam, retorna o valor diferente de zero (1 ou -1)
        if row['GOV.'] != 0:
            return row['GOV.']
        else:
            return row['Governo']

merged_df['gov_orientation'] = merged_df.apply(resolve_gov_orientation, axis=1)

# %%
# Convert the 'data' column to datetime
merged_df['data'] = pd.to_datetime(merged_df['data'], errors='coerce')

# Convert the 'aprovacao' column to int
merged_df['aprovacao'] = pd.to_numeric(merged_df['aprovacao'], errors='coerce').astype('Int64')

# Convert the community size columns to int
for col in ['prev_community_0_size', 'prev_community_1_size', 'prev_community_2_size']:
    merged_df[col] = pd.to_numeric(merged_df[col], errors='coerce').astype('Int64')

# %%
# Truncate 'num_authors' values at 10, keeping values <=10 as is
merged_df['num_authors_trunc'] = merged_df['num_authors'].apply(lambda x: x if x <= 10 else 10)

# Create a new boolean column to tag propositions with more than 10 authors
merged_df['has_more_than_10_authors'] = merged_df['num_authors'] > 10

# %%
merged_df['popularity'] = merged_df['popularity'].fillna(0)

# Substituir valores N/A na coluna 'author_prev_community' por -1 
# (valor fora do intervalo 0-2 para indicar "comunidade desconhecida")
merged_df['author_prev_community'] = merged_df['author_prev_community'].fillna(-1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9260 entries, 0 to 2099179
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        9260 non-null   object
#  1   data                      9260 non-null   datetime64[ns]
#  2   siglaOrgao                9260 non-null   object
#  3   aprovacao                 8914 non-null   Int64
#  4   year                      9260 non-null   int64
#  5   GOV.                      9260 non-null   int64
#  6   Governo                   9260 non-null   int64
#  7   Oposição                  9260 non-null   int64
#  8   author_type               9260 non-null   object
#  9   num_authors               9260 non-null   int64
#  10  theme                     9252 non-null   object
#  11  legislatura               9260 non-null   int64
#  12  content                   9260 non-null   object
#  13  popularity                9260 non-null   float64
#  14  author_prev_community     9260 non-null   float64
#  15  prev_community_0_size     8973 non-null   Int64
#  16  prev_community_1_size     8973 non-null   Int64
#  17  prev_community_2_size     9260 non-null   Int64
#  18  gov_orientation           9260 non-null   int64
#  19  num_authors_trunc         9260 non-null   int64
#  20  has_more_than_10_authors  9260 non-null   bool
# dtypes: Int64(4), bool(1), datetime64[ns](1), float64(2), int64(8), object(5)
# memory usage: 1.5+ MB

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9260 entries, 0 to 2099179
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        9260 non-null   object
#  1   data                      9260 non-null   datetime64[ns]
#  2   siglaOrgao                9260 non-null   object
#  3   aprovacao                 8914 non-null   Int64
#  4   year                      9260 non-null   int64
#  5   GOV.                      9260 non-null   int64
#  6   Governo                   9260 non-null   int64
#  7   Oposição                  9260 non-null   int64
#  8   author_type               9260 non-null   object
#  9   num_authors               9260 non-null   int64
#  10  theme                     9252 non-null   object
#  11  legislatura               9260 non-null   int64
#  12  content                   9260 non-null   object
#  13  popularity                9260 non-null   float64
#  14  author_prev_community     9260 non-null   float64
#  15  prev_community_0_size     8973 non-null   Int64
#  16  prev_community_1_size     8973 non-null   Int64
#  17  prev_community_2_size     9260 non-null   Int64
#  18  gov_orientation           9260 non-null   int64
#  19  num_authors_trunc         9260 non-null   int64
#  20  has_more_than_10_authors  9260 non-null   bool
# dtypes: Int64(4), bool(1), datetime64[ns](1), float64(2), int64(8), object(5)
# memory usage: 1.5+ MB

# %%
merged_df = merged_df.dropna(subset=['aprovacao'])

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8914 entries, 0 to 2099179
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        8914 non-null   object
#  1   data                      8914 non-null   datetime64[ns]
#  2   siglaOrgao                8914 non-null   object
#  3   aprovacao                 8914 non-null   Int64
#  4   year                      8914 non-null   int64
#  5   GOV.                      8914 non-null   int64
#  6   Governo                   8914 non-null   int64
#  7   Oposição                  8914 non-null   int64
#  8   author_type               8914 non-null   object
#  9   num_authors               8914 non-null   int64
#  10  theme                     8906 non-null   object
#  11  legislatura               8914 non-null   int64
#  12  content                   8914 non-null   object
#  13  popularity                8914 non-null   float64
#  14  author_prev_community     8914 non-null   float64
#  15  prev_community_0_size     8627 non-null   Int64
#  16  prev_community_1_size     8627 non-null   Int64
#  17  prev_community_2_size     8914 non-null   Int64
#  18  gov_orientation           8914 non-null   int64
#  19  num_authors_trunc         8914 non-null   int64
#  20  has_more_than_10_authors  8914 non-null   bool
# dtypes: Int64(4), bool(1), datetime64[ns](1), float64(2), int64(8), object(5)
# memory usage: 1.5+ MB

# %%
# Mostrar a contagem de valores nulos em cada coluna de merged_df
print("Valores nulos por coluna em merged_df:")
print(merged_df.isnull().sum())
# Out:
# Valores nulos por coluna em merged_df:
# id                            0
# data                          0
# siglaOrgao                    0
# aprovacao                     0
# year                          0
# GOV.                          0
# Governo                       0
# Oposição                      0
# author_type                   0
# num_authors                   0
# theme                         8
# legislatura                   0
# content                       0
# popularity                    0
# author_prev_community         0
# prev_community_0_size       287
# prev_community_1_size       287
# prev_community_2_size         0
# gov_orientation               0
# num_authors_trunc             0
# has_more_than_10_authors      0
# dtype: int64

# %%
# Preencher valores nulos na coluna 'theme' com "Not defined"
merged_df['theme'] = merged_df['theme'].fillna("Not defined")

# Preencher valores nulos nas colunas 'prev_community_0_size' e 'prev_community_1_size' com zero
merged_df['prev_community_0_size'] = merged_df['prev_community_0_size'].fillna(0)
merged_df['prev_community_1_size'] = merged_df['prev_community_1_size'].fillna(0)

# %%
print(merged_df['aprovacao'].value_counts())
# Out:
# 1    7084
# 0    1830
# Name: aprovacao, dtype: Int64

# %%
# Selecionar as features e o target para o novo dataset
features = [
    'gov_orientation',
    'num_authors_trunc',
    'has_more_than_10_authors'
]
target = 'aprovacao'

# Criar o novo DataFrame apenas com as features e o target
dataset_features_target = merged_df[features + [target]].copy()

# %%
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.metrics import (
    precision_recall_curve, f1_score, classification_report, confusion_matrix, make_scorer, roc_auc_score
)
from sklearn.model_selection import GridSearchCV, StratifiedKFold
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown

print("Splitting X and y while keeping temporal order...")
X = dataset_features_target[features]
y = dataset_features_target[target]

# Identify numeric features for normalization
numeric_features = [
    'popularity',
    'author_prev_community',
    'prev_community_0_size',
    'prev_community_1_size',
    'prev_community_2_size',
    'gov_orientation',
    'num_authors_trunc'
]

# Identify categorical features (if any)
categorical_features = [f for f in features if f not in numeric_features]

print("Performing temporal split (80% train, 20% test)...")
split_idx = int(0.8 * len(X))
X_train = X.iloc[:split_idx].copy()
X_test = X.iloc[split_idx:].copy()
y_train = y.iloc[:split_idx].copy()
y_test = y.iloc[split_idx:].copy()

print("Normalizing numeric features...")
scaler = StandardScaler()
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()
for col in numeric_features:
    if col in X_train_scaled.columns:
        X_train_scaled[col] = scaler.fit_transform(X_train_scaled[[col]])
        X_test_scaled[col] = scaler.transform(X_test_scaled[[col]])

print("Selecting final features for the model...")
X_train_model = X_train_scaled[features]
X_test_model = X_test_scaled[features]

print("Defining F1 scorer for class 'Rejected' (0)...")
f1_reprovada_scorer = make_scorer(f1_score, pos_label=0, average='binary')

# --------------- XGBoost ONLY ---------------
print("Starting GridSearch for XGBoost...")

# Callback function to show GridSearchCV progress
from sklearn.model_selection import ParameterGrid
import time

# Calculate the total number of parameter combinations
neg, pos = y_train.value_counts()   # neg = rejected, pos = approved
scale_pos_weights = [1, neg / pos, 2*neg / pos, 3*neg / pos, 5*neg / pos]
xgb_param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [3, 6, 10],
    'learning_rate': [0.01, 0.1, 0.3],
    'scale_pos_weight': scale_pos_weights,
    'subsample': [0.8, 1.0]
}
total_param_combinations = len(list(ParameterGrid(xgb_param_grid)))
cv_folds = 3
total_fits = total_param_combinations * cv_folds

print(f"GridSearchCV will run {total_param_combinations} parameter combinations x {cv_folds} folds = {total_fits} fits.")

# Callback to show XGBoost progress (per fit)
from tqdm.notebook import tqdm

class VerboseGridSearchCV(GridSearchCV):
    def fit(self, X, y=None, **fit_params):
        # tqdm progress bar
        self._tqdm_bar = tqdm(total=total_fits, desc="GridSearch XGBoost Progress", leave=True)
        # Patch _fit_and_score to update tqdm
        from sklearn.model_selection._validation import _fit_and_score as orig_fit_and_score
        def _fit_and_score(*args, **kwargs):
            result = orig_fit_and_score(*args, **kwargs)
            self._tqdm_bar.update(1)
            return result
        import sklearn.model_selection._validation
        old_func = sklearn.model_selection._validation._fit_and_score
        sklearn.model_selection._validation._fit_and_score = _fit_and_score
        try:
            result = super().fit(X, y, **fit_params)
        finally:
            sklearn.model_selection._validation._fit_and_score = old_func
            self._tqdm_bar.close()
        return result

xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
y_train_inv = 1 - y_train
y_test_inv = 1 - y_test

xgb_grid = VerboseGridSearchCV(
    xgb,
    xgb_param_grid,
    scoring='f1',
    cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=42),
    n_jobs=-1,
    verbose=1
)
xgb_grid.fit(X_train_model, y_train_inv)
print(f"XGBoost (GridSearch) best F1_rejected: {xgb_grid.best_score_:.4f} with params: {xgb_grid.best_params_}")
xgb_best = xgb_grid.best_estimator_
y_proba_inv = xgb_best.predict_proba(X_test_model)[:, 1]
prec_inv, rec_inv, thresh_inv = precision_recall_curve(y_test_inv, y_proba_inv, pos_label=1)
f1_neg_inv = 2 * (prec_inv * rec_inv) / (prec_inv + rec_inv)
best_idx_inv = f1_neg_inv.argmax()
best_thresh_inv = thresh_inv[best_idx_inv] if best_idx_inv < len(thresh_inv) else 0.5
print(f"Best F1_rejected = {f1_neg_inv[best_idx_inv]:.3f} at threshold={best_thresh_inv:.2f}")

y_pred_xgb_f1neg = (y_proba_inv >= best_thresh_inv).astype(int)
y_pred_xgb_f1neg = 1 - y_pred_xgb_f1neg

# --- Visual Confusion Matrix and Metrics Table ---

# Confusion matrix
cm = confusion_matrix(y_test, y_pred_xgb_f1neg)
cm_labels = ["Rejected", "Approved"]

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=cm_labels, yticklabels=cm_labels, cbar=False, linewidths=1.5, linecolor='gray')
plt.xlabel("Predicted")
plt.ylabel("Real Value")
plt.title("Confusion Matrix (XGBoost, best threshold for F1_rejected)")
plt.show()

# Classification report as DataFrame
report_dict = classification_report(
    y_test, y_pred_xgb_f1neg, digits=3, target_names=cm_labels, output_dict=True
)
report_df = pd.DataFrame(report_dict).T
# Only show the classes and 'accuracy', 'macro avg', 'weighted avg'
metrics_to_show = ["Rejected", "Approved", "accuracy", "macro avg", "weighted avg"]
report_df = report_df.loc[metrics_to_show]
# Format floats
report_df = report_df.applymap(lambda x: f"{x:.3f}" if isinstance(x, float) else x)

# AUROC
xgb_auroc = roc_auc_score(y_test, 1 - y_proba_inv)

# Display metrics table
display(Markdown("### Classification Metrics (XGBoost, optimal threshold for F1_rejected)"))
display(report_df.style.set_caption("Classification Metrics (XGBoost)").set_table_styles(
    [{'selector': 'caption', 'props': [('font-size', '16px'), ('font-weight', 'bold')]}]
).set_properties(**{'text-align': 'center'}))

# Display AUROC separately
display(Markdown(f"**XGBoost AUROC (test):** `{xgb_auroc:.4f}`"))

# ----------------- ADD XGBOOST PREDICTIONS TO merged_df -----------------
print("Adding XGBoost predictions to merged_df...")

# 1. Get the indices/ids of the test samples
if 'id' in X_test.columns and 'id' in merged_df.columns:
    print("Using 'id' column from X_test and merged_df for alignment.")
    test_ids = X_test['id'].values
elif 'id' in merged_df.columns:
    print("Using X_test index to fetch 'id' from merged_df.")
    test_ids = X_test.index
else:
    print("No 'id' column found, using index.")
    test_ids = X_test.index

# 2. Get model predictions for the test set (using optimal threshold for F1_rejected)
y_pred_xgb_final = y_pred_xgb_f1neg

# 3. Create a Series with results, indexed by ids
pred_series = pd.Series(y_pred_xgb_final, index=test_ids, name='aprovacao_predita_xgb')

# 4. Add prediction column to merged_df
if 'id' in merged_df.columns:
    if 'id' not in X_test.columns:
        print("Adjusting prediction Series index to match real 'id' values in merged_df.")
        test_ids_real = merged_df.loc[test_ids, 'id']
        pred_series.index = test_ids_real
    # Remove old column if it exists to avoid merge suffix error
    if 'aprovacao_predita_xgb' in merged_df.columns:
        print("Removing existing 'aprovacao_predita_xgb' column from merged_df to avoid merge conflict.")
        merged_df = merged_df.drop(columns=['aprovacao_predita_xgb'])
    print("Merging predictions into merged_df...")
    merged_df = merged_df.merge(pred_series, left_on='id', right_index=True, how='left')
else:
    print("Adding 'aprovacao_predita_xgb' column directly to merged_df (no 'id' column).")
    merged_df['aprovacao_predita_xgb'] = pred_series

print("Predictions added to merged_df.")

# ----------------- XGBOOST FEATURE IMPORTANCE -----------------
print("Calculating XGBoost feature importances...")
importances = xgb_best.feature_importances_
feature_names = X_train_model.columns

importance_df = pd.DataFrame({'feature': feature_names, 'importance': importances})
importance_df = importance_df.sort_values(by='importance', ascending=False)

print("\nFeature importances (XGBoost):")
print(importance_df)

plt.figure(figsize=(10,5))
plt.barh(importance_df['feature'], importance_df['importance'])
plt.xlabel('Importance')
plt.title('Feature Importances - XGBoost')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Splitting X and y while keeping temporal order...
# Performing temporal split (80% train, 20% test)...
# Normalizing numeric features...
# Selecting final features for the model...
# Defining F1 scorer for class 'Rejected' (0)...
# Starting GridSearch for XGBoost...
# GridSearchCV will run 180 parameter combinations x 3 folds = 540 fits.
# e:\Anaconda\envs\votes_prediction\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# GridSearch XGBoost Progress:   0%|          | 0/540 [00:00<?, ?it/s]
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# e:\Anaconda\envs\votes_prediction\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# XGBoost (GridSearch) best F1_rejected: 0.5470 with params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'scale_pos_weight': 3.4962168978562422, 'subsample': 0.8}
# Best F1_rejected = 0.642 at threshold=0.87
# ### Classification Metrics (XGBoost, optimal threshold for F1_rejected)
# <style type="text/css">
# #T_bec9a caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_bec9a_row0_col0, #T_bec9a_row0_col1, #T_bec9a_row0_col2, #T_bec9a_row0_col3, #T_bec9a_row1_col0, #T_bec9a_row1_col1, #T_bec9a_row1_col2, #T_bec9a_row1_col3, #T_bec9a_row2_col0, #T_bec9a_row2_col1, #T_bec9a_row2_col2, #T_bec9a_row2_col3, #T_bec9a_row3_col0, #T_bec9a_row3_col1, #T_bec9a_row3_col2, #T_bec9a_row3_col3, #T_bec9a_row4_col0, #T_bec9a_row4_col1, #T_bec9a_row4_col2, #T_bec9a_row4_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_bec9a">
#   <caption>Classification Metrics (XGBoost)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bec9a_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_bec9a_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_bec9a_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_bec9a_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bec9a_level0_row0" class="row_heading level0 row0" >Rejected</th>
#       <td id="T_bec9a_row0_col0" class="data row0 col0" >0.897</td>
#       <td id="T_bec9a_row0_col1" class="data row0 col1" >0.500</td>
#       <td id="T_bec9a_row0_col2" class="data row0 col2" >0.642</td>
#       <td id="T_bec9a_row0_col3" class="data row0 col3" >244.000</td>
#     </tr>
#     <tr>
#       <th id="T_bec9a_level0_row1" class="row_heading level0 row1" >Approved</th>
#       <td id="T_bec9a_row1_col0" class="data row1 col0" >0.926</td>
#       <td id="T_bec9a_row1_col1" class="data row1 col1" >0.991</td>
#       <td id="T_bec9a_row1_col2" class="data row1 col2" >0.957</td>
#       <td id="T_bec9a_row1_col3" class="data row1 col3" >1539.000</td>
#     </tr>
#     <tr>
#       <th id="T_bec9a_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_bec9a_row2_col0" class="data row2 col0" >0.924</td>
#       <td id="T_bec9a_row2_col1" class="data row2 col1" >0.924</td>
#       <td id="T_bec9a_row2_col2" class="data row2 col2" >0.924</td>
#       <td id="T_bec9a_row2_col3" class="data row2 col3" >0.924</td>
#     </tr>
#     <tr>
#       <th id="T_bec9a_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_bec9a_row3_col0" class="data row3 col0" >0.911</td>
#       <td id="T_bec9a_row3_col1" class="data row3 col1" >0.745</td>
#       <td id="T_bec9a_row3_col2" class="data row3 col2" >0.800</td>
#       <td id="T_bec9a_row3_col3" class="data row3 col3" >1783.000</td>
#     </tr>
#     <tr>
#       <th id="T_bec9a_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_bec9a_row4_col0" class="data row4 col0" >0.922</td>
#       <td id="T_bec9a_row4_col1" class="data row4 col1" >0.924</td>
#       <td id="T_bec9a_row4_col2" class="data row4 col2" >0.914</td>
#       <td id="T_bec9a_row4_col3" class="data row4 col3" >1783.000</td>
#     </tr>
#   </tbody>
# </table>
# **XGBoost AUROC (test):** `0.8599`
# Adding XGBoost predictions to merged_df...
# Using X_test index to fetch 'id' from merged_df.
# Adjusting prediction Series index to match real 'id' values in merged_df.
# Removing existing 'aprovacao_predita_xgb' column from merged_df to avoid merge conflict.
# Merging predictions into merged_df...
# Predictions added to merged_df.
# Calculating XGBoost feature importances...
#
# Feature importances (XGBoost):
#                     feature  importance
# 0           gov_orientation    0.523556
# 2  has_more_than_10_authors    0.254273
# 1         num_authors_trunc    0.222171

# %%
merged_df_preditos = merged_df[merged_df['aprovacao_predita_xgb'].notna()]

# %%
merged_df_preditos
# Out:
#                  id       data siglaOrgao  aprovacao  year  GOV.  Governo  \
# 1361563  2301683-48 2023-03-22       PLEN          1  2023     0        0
# 1361564  946514-132 2023-03-22       PLEN          1  2023     0        0
# 1361565   2351655-7 2023-03-22       PLEN          1  2023     0        0
# 1361569   2352308-8 2023-03-22       PLEN          1  2023     0        0
# 1361570   2352400-8 2023-03-22       PLEN          1  2023     0        0
# ...             ...        ...        ...        ...   ...   ...      ...
# 2090423  2473375-59 2024-12-19       PLEN          1  2024     0        1
# 2096255  2473375-80 2024-12-19       PLEN          1  2024     0        0
# 2099171  2460010-35 2024-12-19       PLEN          0  2024     0       -1
# 2099175  2460010-43 2024-12-19       PLEN          1  2024     0        1
# 2099179  2460010-45 2024-12-19       PLEN          1  2024     0        0
#
#          Oposição  author_type  num_authors  ...  \
# 1361563         0  Deputado(a)            5  ...
# 1361564         0  Deputado(a)           10  ...
# 1361565         0  Deputado(a)           14  ...
# 1361569         0  Deputado(a)           10  ...
# 1361570         0  Deputado(a)            4  ...
# ...           ...          ...          ...  ...
# 2090423        -1  Deputado(a)          252  ...
# 2096255         0  Deputado(a)          252  ...
# 2099171         1  Deputado(a)            6  ...
# 2099175        -1  Deputado(a)            6  ...
# 2099179         0  Deputado(a)            6  ...
#
#                                                    content  popularity  \
# 1361563  Votação da Redação Final. Parecer às Emendas d...    0.000000
# 1361564  Votação da Redação Final. Apresentação da Emen...    0.000000
# 1361565  Acrescenta parágrafo único ao art. 87 e § 3º a...    0.000000
# 1361569  Institui a "Semana Nacional do Uso Consciente ...    0.000000
# 1361570  Altera a Lei nº 13.146, de 2015, para prever o...    0.000000
# ...                                                    ...         ...
# 2090423  Votação em turno único. Parecer às Emendas de ...    0.517787
# 2096255  Votação da Redação Final. Parecer às Emendas d...    0.000000
# 2099171  Altera a Lei nº 14.467, de 16 de novembro de 2...    0.471170
# 2099175  Votação em turno único. Parecer proferido em P...    0.458564
# 2099179  Votação da Redação Final. Parecer proferido em...    0.000000
#
#         author_prev_community  prev_community_0_size  prev_community_1_size  \
# 1361563                   1.0                    441                    155
# 1361564                   1.0                    441                    155
# 1361565                  -1.0                    441                    155
# 1361569                   1.0                    441                    155
# 1361570                   0.0                    441                    155
# ...                       ...                    ...                    ...
# 2090423                   0.0                    392                    198
# 2096255                   0.0                    392                    198
# 2099171                   0.0                    392                    198
# 2099175                   0.0                    392                    198
# 2099179                   0.0                    392                    198
#
#          prev_community_2_size  gov_orientation  num_authors_trunc  \
# 1361563                      0                0                  5
# 1361564                      0                0                 10
# 1361565                      0                0                 10
# 1361569                      0                0                 10
# 1361570                      0                0                  4
# ...                        ...              ...                ...
# 2090423                      0                1                 10
# 2096255                      0                0                 10
# 2099171                      0               -1                  6
# 2099175                      0                1                  6
# 2099179                      0                0                  6
#
#          has_more_than_10_authors  aprovacao_predita_xgb
# 1361563                     False                    1.0
# 1361564                     False                    1.0
# 1361565                      True                    1.0
# 1361569                     False                    1.0
# 1361570                     False                    1.0
# ...                           ...                    ...
# 2090423                      True                    1.0
# 2096255                      True                    1.0
# 2099171                     False                    0.0
# 2099175                     False                    1.0
# 2099179                     False                    1.0
#
# [1783 rows x 22 columns]

# %%
# Cria uma coluna para identificar o tipo de predição (VP, VN, FP, FN)
# Considerando que 'aprovacao' é o valor real e 'aprovacao_predita_xgb' é a previsão

def classificar_predicao(row):
    real = row['aprovacao']
    pred = row['aprovacao_predita_xgb']
    if real == 1 and pred == 1:
        return 'Verdadeiro Positivo'
    elif real == 0 and pred == 0:
        return 'Verdadeiro Negativo'
    elif real == 0 and pred == 1:
        return 'Falso Positivo'
    elif real == 1 and pred == 0:
        return 'Falso Negativo'
    else:
        return 'Outro'

merged_df_preditos['tipo_predicao'] = merged_df_preditos.apply(classificar_predicao, axis=1)

# Agora, crie uma tabela (DataFrame) com cada grupo
tabela_predicoes = merged_df_preditos.groupby('tipo_predicao').size().reset_index(name='quantidade')
tabela_predicoes
# Out:
# C:\Users\Pedro Natanael\AppData\Local\Temp\ipykernel_60412\219703434.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df_preditos['tipo_predicao'] = merged_df_preditos.apply(classificar_predicao, axis=1)
#          tipo_predicao  quantidade
# 0       Falso Negativo          14
# 1       Falso Positivo         122
# 2  Verdadeiro Negativo         122
# 3  Verdadeiro Positivo        1525

# %%
# Agrupa por 'theme' e 'tipo_predicao' e conta a quantidade de cada combinação
tabela_tema_predicao = merged_df_preditos.groupby(['theme', 'tipo_predicao']).size().reset_index(name='quantidade')

# Pivot para facilitar visualização: linhas = tema, colunas = tipo_predicao
tabela_tema_predicao_pivot = tabela_tema_predicao.pivot(index='theme', columns='tipo_predicao', values='quantidade').fillna(0).astype(int)

# Garante que todas as colunas estejam presentes
for col in ['Falso Negativo', 'Falso Positivo', 'Verdadeiro Positivo', 'Verdadeiro Negativo']:
    if col not in tabela_tema_predicao_pivot.columns:
        tabela_tema_predicao_pivot[col] = 0

# Calcula o % de erro para cada tema
tabela_tema_predicao_pivot['percentual_erro'] = (
    (tabela_tema_predicao_pivot['Falso Negativo'] + tabela_tema_predicao_pivot['Falso Positivo']) /
    (tabela_tema_predicao_pivot['Falso Negativo'] + tabela_tema_predicao_pivot['Falso Positivo'] +
     tabela_tema_predicao_pivot['Verdadeiro Positivo'] + tabela_tema_predicao_pivot['Verdadeiro Negativo'])
).fillna(0)

# Ranqueia do menor para o maior percentual de erro
tabela_tema_predicao_rank = tabela_tema_predicao_pivot.sort_values('percentual_erro', ascending=True)

# Exibe a tabela ranqueada com os valores de VP, VN, FP, FN e percentual de erro
tabela_tema_predicao_rank[['percentual_erro', 'Verdadeiro Positivo', 'Verdadeiro Negativo', 'Falso Positivo', 'Falso Negativo']]
# Out:
# tipo_predicao                                percentual_erro  \
# theme
# Previdência e Assistência Social                    0.000000
# Indústria, Comércio e Serviços                      0.000000
# Homenagens e Datas Comemorativas                    0.000000
# Esporte e Lazer                                     0.000000
# Turismo                                             0.000000
# Defesa e Segurança                                  0.010309
# Direito Civil e Processual Civil                    0.019231
# Viação, Transporte e Mobilidade                     0.024390
# Saúde                                               0.033058
# Cidades e Desenvolvimento Urbano                    0.035714
# Comunicações                                        0.043478
# Arte, Cultura e Religião                            0.052632
# Economia                                            0.064516
# Educação                                            0.073684
# Direitos Humanos e Minorias                         0.077491
# Direito Penal e Processual Penal                    0.086957
# Finanças Públicas e Orçamento                       0.092784
# Energia, Recursos Hídricos e Minerais               0.095238
# Administração Pública                               0.101493
# Meio Ambiente e Desenvolvimento Sustentável         0.104167
# Estrutura Fundiária                                 0.125000
# Direito e Justiça                                   0.166667
# Ciência, Tecnologia e Inovação                      0.176471
# Processo Legislativo e Atuação Parlamentar          0.200000
# Trabalho e Emprego                                  0.200000
# Direito e Defesa do Consumidor                      0.250000
# Agricultura, Pecuária, Pesca e Extrativismo         0.285714
#
# tipo_predicao                                Verdadeiro Positivo  \
# theme
# Previdência e Assistência Social                              17
# Indústria, Comércio e Serviços                                 9
# Homenagens e Datas Comemorativas                              25
# Esporte e Lazer                                               16
# Turismo                                                        2
# Defesa e Segurança                                            96
# Direito Civil e Processual Civil                              51
# Viação, Transporte e Mobilidade                               37
# Saúde                                                        115
# Cidades e Desenvolvimento Urbano                              26
# Comunicações                                                  22
# Arte, Cultura e Religião                                      31
# Economia                                                      80
# Educação                                                      84
# Direitos Humanos e Minorias                                  244
# Direito Penal e Processual Penal                             206
# Finanças Públicas e Orçamento                                 73
# Energia, Recursos Hídricos e Minerais                         19
# Administração Pública                                        262
# Meio Ambiente e Desenvolvimento Sustentável                   36
# Estrutura Fundiária                                            7
# Direito e Justiça                                              5
# Ciência, Tecnologia e Inovação                                28
# Processo Legislativo e Atuação Parlamentar                     4
# Trabalho e Emprego                                            12
# Direito e Defesa do Consumidor                                 3
# Agricultura, Pecuária, Pesca e Extrativismo                   15
#
# tipo_predicao                                Verdadeiro Negativo  \
# theme
# Previdência e Assistência Social                               0
# Indústria, Comércio e Serviços                                 0
# Homenagens e Datas Comemorativas                               0
# Esporte e Lazer                                                0
# Turismo                                                        0
# Defesa e Segurança                                             0
# Direito Civil e Processual Civil                               0
# Viação, Transporte e Mobilidade                                3
# Saúde                                                          2
# Cidades e Desenvolvimento Urbano                               1
# Comunicações                                                   0
# Arte, Cultura e Religião                                       5
# Economia                                                      36
# Educação                                                       4
# Direitos Humanos e Minorias                                    6
# Direito Penal e Processual Penal                               4
# Finanças Públicas e Orçamento                                 15
# Energia, Recursos Hídricos e Minerais                          0
# Administração Pública                                         39
# Meio Ambiente e Desenvolvimento Sustentável                    7
# Estrutura Fundiária                                            0
# Direito e Justiça                                              0
# Ciência, Tecnologia e Inovação                                 0
# Processo Legislativo e Atuação Parlamentar                     0
# Trabalho e Emprego                                             0
# Direito e Defesa do Consumidor                                 0
# Agricultura, Pecuária, Pesca e Extrativismo                    0
#
# tipo_predicao                                Falso Positivo  Falso Negativo
# theme
# Previdência e Assistência Social                          0               0
# Indústria, Comércio e Serviços                            0               0
# Homenagens e Datas Comemorativas                          0               0
# Esporte e Lazer                                           0               0
# Turismo                                                   0               0
# Defesa e Segurança                                        1               0
# Direito Civil e Processual Civil                          1               0
# Viação, Transporte e Mobilidade                           1               0
# Saúde                                                     4               0
# Cidades e Desenvolvimento Urbano                          1               0
# Comunicações                                              0               1
# Arte, Cultura e Religião                                  2               0
# Economia                                                  7               1
# Educação                                                  7               0
# Direitos Humanos e Minorias                              19               2
# Direito Penal e Processual Penal                         19               1
# Finanças Públicas e Orçamento                             9               0
# Energia, Recursos Hídricos e Minerais                     2               0
# Administração Pública                                    29               5
# Meio Ambiente e Desenvolvimento Sustentável               4               1
# Estrutura Fundiária                                       0               1
# Direito e Justiça                                         1               0
# Ciência, Tecnologia e Inovação                            6               0
# Processo Legislativo e Atuação Parlamentar                1               0
# Trabalho e Emprego                                        3               0
# Direito e Defesa do Consumidor                            1               0
# Agricultura, Pecuária, Pesca e Extrativismo               4               2

# %%
# Agrupa por 'theme' e 'tipo_predicao' e conta a quantidade de cada combinação
tabela_tema_predicao = merged_df_preditos.groupby(['legislatura', 'tipo_predicao']).size().reset_index(name='quantidade')

# Pivot para facilitar visualização: linhas = tema, colunas = tipo_predicao
tabela_tema_predicao_pivot = tabela_tema_predicao.pivot(index='legislatura', columns='tipo_predicao', values='quantidade').fillna(0).astype(int)

# Garante que todas as colunas estejam presentes
for col in ['Falso Negativo', 'Falso Positivo', 'Verdadeiro Positivo', 'Verdadeiro Negativo']:
    if col not in tabela_tema_predicao_pivot.columns:
        tabela_tema_predicao_pivot[col] = 0

# Calcula o % de erro para cada tema
tabela_tema_predicao_pivot['percentual_erro'] = (
    (tabela_tema_predicao_pivot['Falso Negativo'] + tabela_tema_predicao_pivot['Falso Positivo']) /
    (tabela_tema_predicao_pivot['Falso Negativo'] + tabela_tema_predicao_pivot['Falso Positivo'] +
     tabela_tema_predicao_pivot['Verdadeiro Positivo'] + tabela_tema_predicao_pivot['Verdadeiro Negativo'])
).fillna(0)

# Ranqueia do menor para o maior percentual de erro
tabela_tema_predicao_rank = tabela_tema_predicao_pivot.sort_values('percentual_erro', ascending=True)

# Exibe a tabela ranqueada com os valores de VP, VN, FP, FN e percentual de erro
tabela_tema_predicao_rank[['percentual_erro', 'Verdadeiro Positivo', 'Verdadeiro Negativo', 'Falso Positivo', 'Falso Negativo']]
# Out:
# tipo_predicao  percentual_erro  Verdadeiro Positivo  Verdadeiro Negativo  \
# legislatura
# 57                    0.076276                 1525                  122
#
# tipo_predicao  Falso Positivo  Falso Negativo
# legislatura
# 57                        122              14
